# %% [markdown]
# # dataset/ingest

# %%
import sys
sys.path.append("../..")

from blueflow import notebooks

from blue_options import string
from blue_objects import objects

from roofai import env
from roofai.host import signature
from roofai.dataset.ingest.from_dataset import ingest_from_dataset
from roofai.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🏛️  roofai-6.27.1.abcli-9.474.1.blue_objects-5.240.1.blue_options-4.192.1.torch-2.5.1.Python 3.9.6.Darwin 23.6.0..Jupyter-Notebook,
# built on 19 January 2025, 13:54:38

# %%
cache_object_name = env.ROOFAI_AIRS_CACHE_OBJECT_NAME
dataset_object_name = objects.unique_object("roofai-AIRS-ingest")
# Out:
# 🌀  📂 roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f

# %%
assert ingest_from_dataset(
    input_dataset_path=objects.object_path(cache_object_name),
    ingest_path=objects.object_path(dataset_object_name),
    counts={
        "test": 10,
        "train": 10,
        "val": 10
    },
    log=True,
    in_notebook=True,
)
# Out:
# 🏛️  ingesting from AIRS-cache-v45 -test X 10 + train X 10 + val X 10-384x480-@50%-> torch:roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f
# 🏛️  RoofAIDataset[kind:DatasetKind.AIRS,source:AIRS](AIRS-cache-v45): 3 subset(s): 95 X test + 857 X train + 94 X val - 2 class(es): other, roof
# 🏛️  RoofAIDataset[kind:DatasetKind.CAMVID,source:AIRS](roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f): 3 subset(s): 0 X test + 0 X train + 0 X val - 2 class(es): other, roof
# 🌀  blue_objects.path.create(/Users/kamangir/storage/abcli/roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f/SegNet-Tutorial/CamVid/test)
# 🌀  blue_objects.path.create(/Users/kamangir/storage/abcli/roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f/SegNet-Tutorial/CamVid/testannot)
# 🌀  blue_objects.path.create(/Users/kamangir/storage/abcli/roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f/SegNet-Tutorial/CamVid/train)
# ...

# %%
assert notebooks.upload(dataset_object_name)
# Out:
# upload: ../../../../storage/abcli/roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f/SegNet-Tutorial/CamVid/test/christchurch_1011-00000-00960.png to s3://kamangir/bolt/roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f/SegNet-Tutorial/CamVid/test/christchurch_1011-00000-00960.png
# upload: ../../../../storage/abcli/roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f/SegNet-Tutorial/CamVid/test/christchurch_1011-00000-00000.png to s3://kamangir/bolt/roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f/SegNet-Tutorial/CamVid/test/christchurch_1011-00000-00000.png
# upload: ../../../../storage/abcli/roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f/SegNet-Tutorial/CamVid/test/christchurch_1011-00000-01440.png to s3://kamangir/bolt/roofai-AIRS-ingest-2025-01-19-13-54-38-pm139f/SegNet-Tutorial/CamVid/test/christchurch_1011-00000-01440.png
# ...

# %%
# END
