# %% [markdown]
# # Google Maps API

# %%
from blueflow import notebooks

import math
import numpy as np

from blue_options import string
from blue_objects import objects

from roofai.host import signature
from roofai.google_maps.api.static import get as get_static_image
from roofai.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🏛️  roofai-6.122.1.abcli-9.536.1.blue_objects-5.322.1.blue_options-4.223.1.torch-2.5.1.Python 3.9.6.Darwin 23.6.0..Jupyter-Notebook,
# built on 15 February 2025, 22:09:52

# %%
object_name = objects.unique_object("fascinating-magic")
object_path = objects.object_path(object_name)

filename = objects.path_of(
    filename=f"{string.timestamp()}.png",
    object_name=object_name,
    )
# Out:
# 🌀  📂 fascinating-magic-2025-02-15-22-09-52-9myhnr

# %% [markdown]
# ---

# %%
lat = 53.343318
lon = -2.650661
zoom = 20
maptype = "satellite"
size = "647x640"

# %%
success, image, metadata = get_static_image(
        lat=lat,
        lon=lon,
        zoom=zoom,
        maptype=maptype,
        size=size,
        filename=filename,
    )
assert success
# Out:
# 🏛️  roofai.roofai.google_maps.api.static.get: center:53.343318,-2.650661, zoom:20, size:647x640, maptype:satellite
# 🏛️  -> /Users/kamangir/storage/abcli/fascinating-magic-2025-02-15-22-09-52-9myhnr/2025-02-15-22-09-52-30uix1.png
# 🏛️  gsd: 0.09 m
# ⚠️  🏛️  image size mismatch: 640x640:uint8 != 647x640
# 🏛️  image size = 647 px x 640 px = 57.67 m x 57.04 m = 0.00051 deg x 0.00086 deg

# %%
notebooks.imshow(filename)
# Out:
# <table><tr><td><img src="data:image/gif;base64,..."></td></tr></table>

# %% [markdown]
# ---

# %%
assert notebooks.upload(object_name)
# Out:
# upload: ../../../storage/abcli/fascinating-magic-2025-02-15-22-09-52-9myhnr/2025-02-15-22-09-52-30uix1.png to s3://kamangir/bolt/fascinating-magic-2025-02-15-22-09-52-9myhnr/2025-02-15-22-09-52-30uix1.png
# 🌀  ⏺️  fascinating-magic-2025-02-15-22-09-52-9myhnr | 00001
# 🌀  ⬆️  /Users/kamangir/storage/abcli/fascinating-magic-2025-02-15-22-09-52-9myhnr/2025-02-15-22-09-52-30uix1.png
# 🏃 View run fascinating-magic-2025-02-15-22-09-52-9myhnr-00001 at: https://dbc-3ac1d106-bf0c.cloud.databricks.com/ml/experiments/709953300445957/runs/f85d89810b1245a782544839f74db699
# 🧪 View experiment at: https://dbc-3ac1d106-bf0c.cloud.databricks.com/ml/experiments/709953300445957
# 🌀  ⏹️  fascinating-magic-2025-02-15-22-09-52-9myhnr

# %%
# END
